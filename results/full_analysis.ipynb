# %% [markdown]
# # Phân tích thống kê kết quả thực nghiệm - Tuần 8
# **Nhóm:** 4
# **Đề tài:** RT-SWT-005 (Proactive Bug Discovery via Agentic Exploration)
#
# Sổ tay phân tích này thực hiện các bước sau:
# 1. Tính metric F2P Rate trung bình cấp độ Test Suite cho cả 2 cấu hình (Agentic và Baseline).
# 2. Tiến hành kiểm định phi tham số Wilcoxon signed-rank test (one-tailed) để đánh giá sự vượt trội của hệ tác nhân.
# 3. Tính toán Effect Size bằng Cliff's delta.
# 4. Xuất báo cáo tóm tắt ra file `results/summary.csv`.

# %%
# Chạy trực tiếp script phân tích từ thư mục scripts
# %run ../scripts/analyze_full_experiment.py

# %% [markdown]
# ## Vẽ Biểu Đồ Kết Quả
#
# Chạy cell dưới đây để tạo các biểu đồ đạt chuẩn 300 DPI phục vụ báo cáo khoa học (lưu vào thư mục `figures/`):

# %%
# Chạy trực tiếp script vẽ biểu đồ
# %run ../scripts/generate_figures.py
